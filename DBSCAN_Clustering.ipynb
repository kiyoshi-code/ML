# %%
#non-linearly seperable dataset
#also used for outlier detection

# %%
# requirements:
# 1. min point=4
# 2. epsilon(r)=0.5
# 3. core point-> no. of points formed >= min points
# 4. boundary point-> no. of points formed < min points
# 5. noise point-> outlier

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=250, noise=0.05)
df={"data1":x[:,0], "data2":x[:,1]}
dataset=pd.DataFrame(df)
dataset.head(5)
# Out:
#       data1     data2
# 0  0.700758 -0.400458
# 1 -0.355646  0.821795
# 2  1.993009  0.422840
# 3  1.910731  0.032268
# 4 -0.731767  0.744472

# %%
sns.scatterplot(x="data1", y="data2", data=dataset)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=0.3, min_samples=5)
dataset["predict"]=db.fit_predict(dataset)

# %%
sns.scatterplot(x="data1", y="data2", data=dataset, hue="predict")
plt.show()

# %%
sns.scatterplot(x="data1", y="data2", data=dataset, hue=y)
plt.show()
